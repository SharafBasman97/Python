# %%
## Student name : SHARAF KHALIL IBRAHEEM
## STUDENT ID   : 21510641
## HOME WORK    : TREASURE GAME
## DATE         : 26/10/2018
print("WELCOME TO THE GAME")
print("THE Challenge to Find The Treasure")
import random 
import math
x=random.randint(0,100)
counter =0 
l=[]
choice = 'y'
number = input("Enter Your Predict number  ")
x2=0
x1=int(number)
temp=0
temp2=0
while choice == 'y' or choice == 'yes':
   
    
    if abs(int(number)- x)<11 :
        print("close \n")
    else:
        print("faraway\n ")
        
    while int(number) != x:
        counter = counter+1 
    
        if int(number)>=101 or int(number)<0  :
            print("OUT OF BOUNDS")
            
        elif counter>1:
            
            if temp < temp2 :
                print("closer")
            
   
            else:      
                print('\n')
                print("farther")
            
        print('\n')
        l.append(number)
        print(l)
        print('\n')
        x2 = x1
        number = input("Enter Your Predict number!  ")
        x1=int(number) 
        temp = abs(x1-x)          
        temp2 = abs(x2-x)
        
    print("YOU WIN")
    counter = counter + 1
    print("The number of moves is : ")
    print(counter)
    print('\n')
    choice = input("DO YOU WANT TO PLAY AGAN y/n ")
    print('\n')
    if choice =='y':
        number = input("Enter Your Predict number!  ")
        x=random.randint(0,100)
        l=[]
        counter = 0
    
print("THE END WITH LOVE ")
# Out:
# WELCOME TO THE GAME
# THE Challenge to Find The Treasure
# Enter Your Predict number  50
# faraway
#
#
#
# ['50']
#
#
# Enter Your Predict number!  50
#
#
# farther
#
#
# ['50', '50']
#
#
# Enter Your Predict number!  53
#
#
# farther
#
#
# ['50', '50', '53']
#
#
# Enter Your Predict number!  25
# closer
#
#
# ['50', '50', '53', '25']
#
#
# Enter Your Predict number!  22
#
#
# farther
#
#
# ['50', '50', '53', '25', '22']
#
#
# Enter Your Predict number!  23
# closer
#
#
# ['50', '50', '53', '25', '22', '23']
#
#
# Enter Your Predict number!  26
# closer
#
#
# ['50', '50', '53', '25', '22', '23', '26']
#
#
# Enter Your Predict number!  29
# YOU WIN
# The number of moves is :
# 8
#
#
# DO YOU WANT TO PLAY AGAN y/n y
#
#
# Enter Your Predict number!  33
# faraway
#
#
#
# ['33']
#
#
# Enter Your Predict number!  66
#
#
# farther
#
#
# ['33', '66']
#
#
# Enter Your Predict number!  55
# closer
#
#
# ['33', '66', '55']
#
#
# Enter Your Predict number!  48
# closer
#
#
# ...
